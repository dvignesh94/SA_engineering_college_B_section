# %%
pip install openpyxl

# %%
import pandas as pd

# Read the Excel file
data = pd.read_excel("/Users/vignesh/Documents/data works/May data works/corr_analysis_v2.xlsx", engine='openpyxl')

# Check if the data contains any non-UTF-8 characters
if any(data.columns.str.contains('ï»¿')):
    data = pd.read_excel("/Users/vignesh/Documents/data works/May data works/corr_analysis_v2.xlsx", engine='openpyxl', header=None)

# %%
# Specify the columns of interest
columns_of_interest = [
    'What grade level is your child in?',
    'What would you like help with today?',
    'What type of support are you interested in?',
    'How much help do you think your child needs to achieve their goal?',
    'How soon are you looking to get started?',
    'Lead Stage'
]

# Check for missing values in the specified columns
for column in columns_of_interest:
    missing_values = data_encoded[column].isnull().sum()
    print(f"Number of missing values in '{column}': {missing_values}")
# Out:
# Number of missing values in 'What grade level is your child in?': 0
# Number of missing values in 'What would you like help with today?': 0
# Number of missing values in 'What type of support are you interested in?': 0
# Number of missing values in 'How much help do you think your child needs to achieve their goal?': 0
# Number of missing values in 'How soon are you looking to get started?': 0
# Number of missing values in 'Lead Stage': 0

# %%
# Specify the categorical variables for encoding
categorical_vars = ['What grade level is your child in?', 'What would you like help with today?','What type of support are you interested in?','How much help do you think your child needs to achieve their goal?','How soon are you looking to get started?','Lead Stage']

# Apply one-hot encoding
one_hot_encoded = pd.get_dummies(data[categorical_vars])
print("sucess")
# Out:
# sucess

# %%
# Concatenate the one-hot encoded columns with the original dataset
data_encoded = pd.concat([data, one_hot_encoded], axis=1)

# %%
# List the available variables of interest
variables_of_interest = data_encoded.columns.tolist()

# Print the variable names
print("Available variables of interest:")
for variable in variables_of_interest:
    print(variable)
# Out:
# Available variables of interest:
# What grade level is your child in?
# What would you like help with today?
# What type of support are you interested in?
# How much help do you think your child needs to achieve their goal?
# How soon are you looking to get started?
# Lead Stage
# What grade level is your child in?_Elementary (Kindergarten - 5th grade)
# What grade level is your child in?_High School (9th - 12th grade)
# What grade level is your child in?_Middle School (6th - 8th grade)
# What would you like help with today?_Academics
# What would you like help with today?_Smart Study Habits
# What would you like help with today?_Test Prep (Like SBAC, NJSLA, CMT, STAAR)
# What type of support are you interested in?_Not sure
# What type of support are you interested in?_Not sure, Private 1-on-1 Tutoring
# What type of support are you interested in?_Not sure, Private 1-on-1 Tutoring, Smart Study Habits, Self-Guided AI Learning App
# ...

# %%
# Specify the variables for correlation analysis
variables_of_interest = [
    'What grade level is your child in?',
    'What would you like help with today?',
    'What type of support are you interested in?',
    'How much help do you think your child needs to achieve their goal?',
    'How soon are you looking to get started?',
    'Lead Stage'
]

# Calculate the correlation matrix
correlation_matrix = data_encoded[variables_of_interest].corr()

# %%
print(correlation_matrix)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Display the correlation matrix
print(correlation_matrix.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Convert the columns to numeric data type
data_encoded[variables_of_interest] = data_encoded[variables_of_interest].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/wk/nhm5d5m93x5312_p501n8q2r0000gn/T/ipykernel_10035/72895213.py in <module>
#       1 # Convert the columns to numeric data type
# ----> 2 data_encoded[variables_of_interest] = data_encoded[variables_of_interest].astype(float)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
import pandas as pd

# Read the Excel file
data = pd.read_excel("/Users/vignesh/Documents/data works/May data works/corr_analysis_v1.xlsx", engine='openpyxl')

# Specify the categorical variables for encoding
categorical_vars = [
    'What grade level is your child in?',
    'What would you like help with today?',
    'Which best describes why youre seeking help for your child?',
    'What type of support are you interested in?',
    'How much help do you think your child needs to achieve their goal?',
    'How soon are you looking to get started?',
    'Lead Stage'
]

# Apply one-hot encoding
one_hot_encoded = pd.get_dummies(data[categorical_vars])

# Concatenate the one-hot encoded columns with the original dataset
data_encoded = pd.concat([data, one_hot_encoded], axis=1)

# Specify the variables for correlation analysis
variables_of_interest = [
    'What grade level is your child in?',
    'What would you like help with today?',
    'Which best describes why youre seeking help for your child?',
    'What type of support are you interested in?',
    'How much help do you think your child needs to achieve their goal?',
    'How soon are you looking to get started?',
    'Lead Stage'
]

# Calculate the correlation matrix
correlation_matrix = data_encoded[variables_of_interest].corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(data_encoded.columns)
# Out:
# Index(['What grade level is your child in?',
#        'What would you like help with today?',
#        'Which best describes why youre seeking help for your child?',
#        'What type of support are you interested in?',
#        'How much help do you think your child needs to achieve their goal?',
#        'How soon are you looking to get started?',
#        'Alright! We can definitely help! Please enter your email to continue designing the personalized learning solution. ',
#        'Lead Stage',
#        'What grade level is your child in?_Elementary (Kindergarten - 5th grade)',
#        'What grade level is your child in?_High School (9th - 12th grade)',
#        ...
#        'Lead Stage_Pursuit', 'Lead Stage_Pusuit', 'Lead Stage_Recycled Lead',
#        'Lead Stage_Recycled Leads', 'Lead Stage_Reschedule',
#        'Lead Stage_Scheduled', 'Lead Stage_Schedules', 'Lead Stage_Subscriber',
#        'Lead Stage_Test Lead', 'Lead Stage_pursuit'],
#       dtype='object', length=142)

# %%
# Specify the variables for correlation analysis
variables_of_interest = [
    'What grade level is your child in?',
    'What would you like help with today?',
    'Which best describes why youre seeking help for your child?',
    'What type of support are you interested in?',
    'How much help do you think your child needs to achieve their goal?',
    'How soon are you looking to get started?',
    'Lead Stage'
]

# Calculate the correlation matrix
correlation_matrix = data_encoded[variables_of_interest].corr()

# %%
for column in variables_of_interest:
    missing_values = data_encoded[column].isnull().sum()
    print(f"Number of missing values in '{column}': {missing_values}")
# Out:
# Number of missing values in 'What grade level is your child in?': 0
# Number of missing values in 'What would you like help with today?': 0
# Number of missing values in 'Which best describes why youre seeking help for your child?': 0
# Number of missing values in 'What type of support are you interested in?': 0
# Number of missing values in 'How much help do you think your child needs to achieve their goal?': 0
# Number of missing values in 'How soon are you looking to get started?': 0
# Number of missing values in 'Lead Stage': 0

# %%
for column in variables_of_interest:
    unique_values = data_encoded[column].unique()
    print(f"Unique values in '{column}': {unique_values}")
    print(f"Number of unique values in '{column}': {len(unique_values)}")
# Out:
# Unique values in 'What grade level is your child in?': ['Elementary (Kindergarten - 5th grade)' 'Middle School (6th - 8th grade)'
#  'High School (9th - 12th grade)']
# Number of unique values in 'What grade level is your child in?': 3
# Unique values in 'What would you like help with today?': ['Academics' 'Smart Study Habits'
#  'Test Prep (Like SBAC, NJSLA, CMT, STAAR)']
# Number of unique values in 'What would you like help with today?': 3
# Unique values in 'Which best describes why youre seeking help for your child?': ['They need to become more confident in math'
#  'They need to become more confident in math, They need to improve their math grade/scores'
#  'I want them to be ready to get into top University or Ivy League school'
#  'They struggle in math and needs help'
#  'They need to improve their math grade/scores, They need to become more confident in math, I want them to be ready to get into top University or Ivy League school, They need math homework help'
# ...

# %%
import pandas as pd

# Read the Excel file
data = pd.read_excel("/Users/vignesh/Documents/data works/May data works/corr_analysis_v2.xlsx", engine='openpyxl')

# Specify the categorical variables for encoding
categorical_vars = [
    'What grade level is your child in?',
    'What would you like help with today?',
    'What type of support are you interested in?',
    'How much help do you think your child needs to achieve their goal?',
    'How soon are you looking to get started?',
    'Lead Stage'
]

# Apply one-hot encoding
one_hot_encoded = pd.get_dummies(data[categorical_vars])

# Concatenate the one-hot encoded columns with the original dataset
data_encoded = pd.concat([data, one_hot_encoded], axis=1)

# Calculate the correlation matrix
correlation_matrix = data_encoded.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                                                     What grade level is your child in?_Elementary (Kindergarten - 5th grade)  \
# What grade level is your child in?_Elementary (...                                           1.000000
# What grade level is your child in?_High School ...                                          -0.450294
# What grade level is your child in?_Middle Schoo...                                          -0.783479
# What would you like help with today?_Academics                                               0.024961
# What would you like help with today?_Smart Stud...                                          -0.007247
# ...                                                                                               ...
# Lead Stage_Scheduled                                                                         0.130558
# Lead Stage_Schedules                                                                         0.040744
# ...
